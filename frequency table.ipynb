# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
current_palette = sns.color_palette("Paired", 10)
sns.set_palette(current_palette)

# %%
df = pd.read_csv("datasets/countries.csv")
counts = df['Country'].value_counts() # counts is a one-dimentional array of indexed data, i.e. a Series
# print(type(counts))

print(counts)
# Out:
# China       12
# US          10
# India        8
# Japan        8
# Germany      3
# Mexico       3
# England      2
# Canada       2
# Pakistan     1
# Sweden       1
# Name: Country, dtype: int64

# %%
sns.set_style("white")
plt.figure(figsize=(7.5,5))
ax = counts.plot.bar(alpha=0.7)
plt.locator_params(axis='y', nbins=14) # change the number of ticks
plt.xticks(rotation=50)
plt.xlabel("Country")
plt.ylabel("Frequency")
sns.despine()
plt.show()
